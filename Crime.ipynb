# %%
import pandas as pd
import numpy as np
import scipy.stats as sts

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

import requests
from bs4 import BeautifulSoup

from lxml import etree as et
import numpy.linalg as la

# %% [markdown]
# # Начало работы с данными

# %%
# Преступность в России: 2003 – 2020 годы
# Информация о преступности в России за каждый месяц с 2003 по 2020-ый годы
# общее число преступлений, тяжкие и особо тяжкие, причинившие особо крупный ущерб, экологические,
# терроризм, экстремизм, убийство и покушение на убийство, тяжкое причинение вреда здоровью,
# изнасилование и покушение на изнасилование.
df = pd.read_csv('https://hubofdata.ru/dataset/f426ad0e-8dc1-44e2-8b37-e361ccb7b564/resource/3d3c7a68-b047-48d2-94c0-54d01b1abb39/download/crime.csv')
print(df.shape)
df.head()
# Out:
# (205, 16)
#         month  Total_crimes   Serious  Huge_damage  Ecological  Terrorism  \
# 0  01.01.2003      214587.0   88203.0      20162.0      1216.0      630.0
# 1  01.02.2003      221928.0   88863.0      20889.0      1701.0      678.0
# 2  01.03.2003      248452.0  101349.0      24053.0      1817.0      809.0
# 3  01.04.2003      236299.0   91625.0      19754.0      2449.0      892.0
# 4  01.05.2003      230931.0   89615.0      17519.0      3530.0      796.0
#
#    Extremism  Murder  Harm_to_health   Rape    Theft  Vehicle_theft  \
# 0       13.0  2749.0          5559.0  574.0  81014.0         3549.0
# 1        5.0  2444.0          4732.0  515.0  95970.0         3697.0
# 2       10.0  2864.0          4851.0  560.0  79420.0         4327.0
# 3       10.0  2919.0          4722.0  668.0  95215.0         5345.0
# 4       20.0  2713.0          4895.0  688.0  94505.0         6374.0
#
#    Fraud_scam  Hooligan    Drugs  Weapons
# 0      7731.0   10560.0  16006.0   4661.0
# ...

# %% [markdown]
# 1. В период с 2003 по 2020 год мы можем увидеть общую тенденцию на снижение количества преступлений к ближе к текущему моменту времени

# %%
df['Total_crimes'].plot(kind='line', figsize=(8, 4), title='Total_crimes')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# 2. Раз в год можно увидеть резкий скачок количества и затем после этого резкое падение
# Гипотеза: это может быть связано с закрытием годовой отчётности на местах, благодаря чему возбуждается большее количество преступлений
# 3. На графике мы можем увидеть, что сильная существует прямая связь между общим количеством преступлений и преступлениями, относящимися к категориям тяжких или особо тяжких

# %%
df.plot(kind='scatter', x='Total_crimes', y='Serious', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df['Huge_damage'].plot(kind='hist', bins=20, title='Huge_damage')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# 4. Частота количества преступлений, причинивших особо крупный ущерб не напрямую зависит от их количества, так как мы можем увидеть на гистограмме два максимума: абсолютный и локальный, причём около себя они организуют два различных распределения со смещением влево и вправо

# %%
sns.
# Out:
#   File "<ipython-input-43-40c5c93bca4b>", line 1
#     sns.
#         ^
# SyntaxError: invalid syntax

# %%
pip install requests beautifulsoup4 selenium
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 52.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.7/467.7 kB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.0 MB/s eta 0:00:00
# ...

# %%
video_url = "https://www.youtube.com/watch?v=q6ApUMyGGWA"

# %% [markdown]
# # Парсинг таблицы с сайта

# %%
url_migr = 'https://proza.ru/2023/04/01/1612?ysclid=lw0jh2jc99760797084'

page = requests.get(url_migr)
page
# Out:
# <Response [200]>

# %%
import requests
# отправляем запрос с заголовками по нужному адресу
req = requests.get('https://proza.ru/2023/04/01/1612?ysclid=lw0jh2jc99760797084')
# считываем текст HTML-документ
src = req.text

# %%
soup = BeautifulSoup(src, 'html.parser')

# %%
text = str(soup)

# %% [markdown]
# В таблице ниже указаны данные про миграционный прирост (+сколько человек прибыло и выбыло)

# %%
def find_text_1(text, keyword):
    index = text.find(keyword)
    if index != -1:
        return text[index + len(keyword):index + len(keyword) + 2520]
    else:
        return "Ключевое слово не найдено в тексте"

# Пример текста для поиска
text = str(soup)

# Вызываем функцию и выводим результат
result_1 = find_text_1(text, 'Таблица 1')

# Разбиваем текст на строки и удаляем пустые строки
rows = [row.strip() for row in result_1.split('\n') if row.strip()]

# Создаем список списков для таблицы
table_data = []
for row in rows:
    # Разбиваем строку на ячейки, используя пробелы как разделитель
    cells = row.split()
    table_data.append(cells)

# Создаем DataFrame из списка списков
df_1 = pd.DataFrame(table_data)

# Названия столбцов
column_names = ['Год', 'Прибыло всего', 'Выбыло всего', 'Миграционный прирост', 'Пусто' ]

# Присваиваем названия столбцам ДФ
df_1.columns = column_names

# Переименование
df_1 = df_1.rename(columns={'0': 'Год', '1': 'Прибыло всего', '2': 'Выбыло всего', '3': 'Миграционный прирост', '4': 'Пусто' })
# Удаляем последний столбец
df_1 = df_1.iloc[:, :-1]
# Список индексов строк для удаления
rows_to_drop = [0, 1, 2, 3, 4, 5, 6, 11, 13, 22, 25, 43]

# Удаление строк по индексам (полностью пустые строки, в тексте были абзацами)
df_1 = df_1.drop(rows_to_drop)
# Сброс индекса и удаление старого индекса (reset_index : создает новый индекс, начинающийся с 0)
df_1 = df_1.reset_index(drop=True)

# Удаление из последнего столбца
df_1.iloc[:, -1] = df_1.iloc[:, -1].str.replace("<br/>", "")

# Сохраняем DataFrame в CSV файл
df.to_csv('table.csv', index=False, encoding='utf-8')
# Выводим DataFrame
print(df_1.shape)
df_1.head()
# Out:
# (32, 4)
#     Год Прибыло всего Выбыло всего Миграционный прирост
# 0  1990        913223       729467               183756
# 1  1991        692238       675497                16741
# 2  1992        926020       673143               252877
# 3  1993        923280       483028               440252
# 4  1994       1146735       337121               809614

# %%
df_1['Выбыло всего'] = pd.to_numeric(df_1['Выбыло всего'], errors='coerce')

plt.figure(figsize=(12, 6))
plt.bar(df_1['Год'], df_1['Выбыло всего'], color='skyblue')
plt.xlabel('Год')
plt.ylabel('Выбыло всего')
plt.title('Столбчатая диаграмма выбытия за год')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df_1['Год'], df_1['Выбыло всего'], marker='o', color='b', label='Выбыло всего')
plt.plot(df_1['Год'], df_1['Выбыло всего'].rolling(window=2).mean(), color='r', linestyle='--', label='Скользящее среднее')
plt.xticks(rotation=45)
plt.xlabel('Год')
plt.ylabel('Выбыло всего')
plt.title('График выбытия за год с скользящим средним')
plt.legend()

plt.show()

# %%
df_1['Миграционный прирост'] = pd.to_numeric(df_1['Миграционный прирост'], errors='coerce')

plt.figure(figsize=(12, 6))
plt.bar(df_1['Год'], df_1['Миграционный прирост'], color='skyblue')
plt.xlabel('Год')
plt.ylabel('Миграционный прирост')
plt.title('Столбчатая диаграмма МП за год')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# МП - миграционный прирост в количестве человек

# %% [markdown]
# Таблица ниже говорит о Миграционном приросте за десятилетия в различных СНГ странах, которые могут помочь сделать выводы о том, есть ли корреляция между мигрантами и возросшей преступностью, есть ли каузация.

# %%
def find_text_2(text, keyword):
    index = text.find(keyword)
    if index != -1:
        return text[index + len(keyword):index + len(keyword) + 1703]
    else:
        return "Ключевое слово не найдено в тексте"

# Пример текста для поиска
text = str(soup)

# Вызываем функцию и выводим результат
result_2 = find_text_2(text, 'Таблица 2')

# Разбиваем текст на строки и удаляем пустые строки
rows = [row.strip() for row in result_2.split('\n') if row.strip()]

# Создаем список списков для таблицы
table_data2 = []
for row in rows:
    # Разбиваем строку на ячейки, используя пробелы как разделитель
    cells2 = row.split()
    table_data2.append(cells2)

# Создаем DataFrame из списка списков
df_2 = pd.DataFrame(table_data2)
# Названия столбцов
column_names2 = ['Страна', 'МП 1990-1999 гг.', 'МП 2000-2009 гг.', 'МП 2010-2019 гг.', 'МП за все годы', 'Пусто1', 'Пусто2' ]

# Присваиваем названия столбцам DataFrame
df_2.columns = column_names2

# Переименование
df_2 = df_2.rename(columns={'0': 'Страна', '1': 'МП 1990-1999 гг.', '2': 'МП 2000-2009 гг.', '3': 'МП 2010-2019 гг.', '4': 'МП за все годы', '5': 'Пусто1', '6': 'Пусто2' })
# Удаляем последний столбец
df_2 = df_2.iloc[:, :-2]
# Список индексов строк для удаления
rows_to_drop2 = [0, 1, 2, 3, 8, 15, 20, 24, 25]

# Удаление строк по индексам
df_2 = df_2.drop(rows_to_drop2)
# Сброс индекса и удаление старого индекса (reset_index : создает новый индекс, начинающийся с 0)
df_2 = df_2.reset_index(drop=True)

# Удаление из последнего столбца
df_2.iloc[:, -1] = df_2.iloc[:, -1].str.replace("<br/>", "")

# Сохраняем DataFrame в CSV файл
df.to_csv('table.csv', index=False, encoding='utf-8')
# Выводим DataFrame
print(df_2.shape)
df_2
# Out:
# (17, 5)
#           Страна МП 1990-1999 гг. МП 2000-2009 гг. МП 2010-2019 гг.  \
# 0         Грузия           354822            77727            42012
# 1    Азербайджан           339205            97111            42012
# 2        Армения           186773            49202            35114
# 3     Закавказье           880800           324040           414758
# 4      Казахстан          1444961           402270           338779
# 5     Узбекистан           633119           321563           293364
# 6    Таджикистан           345044           101713           288606
# 7       Киргизия           280040           150192           184442
# 8   Туркменистан           115148            43822            33582
# 9        Средняя             Азия          2818312          1019560
# 10        Латвия           111441             7027             6566
# 11       Эстония            69265             2024             4122
# 12         Литва            51072             2879             3023
# ...

# %%
df_2['МП за все годы'] = pd.to_numeric(df_2['МП за все годы'], errors='coerce')

plt.figure(figsize=(12, 6))
plt.bar(df_2['Страна'], df_2['МП за все годы'])
plt.xlabel('Страна')
plt.ylabel('МП за все время')
plt.title('Столбчатая диаграмма МП за все время по странам')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# *Виолончель (как и ящик с усами) пока не построили, так как для этого надо таблицу перестроить в другой вид (создать отдельно колонку с дифференцированным жанром, нам было бы прикольно такое сделать по видам преступлений, пока в раздумьях как в принципе переформатировать в необходимый формат).
# С облаками рассеивания можно сделать до и после какого-то момента, пока пытаемся определить границы и необходимость данного графика.*

# %% [markdown]
# # Разводы и безработица

# %%
# данные по областям, количество разводов на 100 браков
# делаем предположение, что более высокое число разводов может повлиять на более высокую преступность
df_razvod = pd.read_csv('https://russia.duck.consulting/maps/98.csv')
del df_razvod['Unnamed: 0'] # удаляем пустой столбец, который был пробелом
# Меняем названия столбцов
df_razvod.columns = ['Регион', 'Количество разводов']

df_razvod
# Out:
#                              Регион  Количество разводов
# 0                    Алтайский край                72.13
# 1                  Амурская область                70.83
# 2             Архангельская область                68.25
# 3              Астраханская область                63.64
# 4                      Башкортостан                61.29
# ..                              ...                  ...
# 79                          Чувашия                61.11
# 80       Чукотский автономный округ                73.24
# 81                           Якутия                66.15
# 82  Ямало-Ненецкий автономный округ                74.03
# 83              Ярославская область                62.12
#
# [84 rows x 2 columns]

# %%
# безработица в России
url = 'https://rosstat.gov.ru/storage/mediabank/Trud-1_15-s.xlsx'
df_bezrab = pd.read_excel(url, sheet_name=2)  # для чтения третьей страницы
# необходимо почистить от пропусков и адаптировать таблицу
df_bezrab
# Out:
#                                           К содержанию  Unnamed: 1  \
# 0    Уровень участия в рабочей силе населения в воз...         NaN
# 1     (по данным выборочных обследований рабочей силы)         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN      2017.0
# 4                                 Российская Федерация        62.8
# ..                                                 ...         ...
# 97                                 Сахалинская область        69.1
# 98                        Еврейская автономная область        61.8
# 99                          Чукотский автономный округ        79.5
# 100  1) Без учета статистической информации по Доне...         NaN
# 101    2) Данные пересчитаны с учетом итогов ВПН-2020.         NaN
#
#      Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6   Unnamed: 7
# 0           NaN         NaN         NaN         NaN        NaN          NaN
# ...

# %% [markdown]
# # **Парсинг данных с ютуба**

# %%
import requests
from bs4 import BeautifulSoup

# %%
class YoutubeScraper:
    def __init__(self, url):
        self.url = url

    def scrape_video_count(self):
        content = requests.get(self.url)
        soup = BeautifulSoup(content.text, "html.parser")
        view_count = soup.find("div", {"class": "watch-view-count"}).text
        return view_count

# %%
import requests

def get_video_urls(channel_id):
    api_key = "AIzaSyCcGra7-G3ZDEIK9-lDwfW2UAO-oB62PLk"
    url = f"https://www.googleapis.com/youtube/v3/search?key={api_key}&channelId={channel_id}&part=snippet,id&order=date&maxResults=50"
    response = requests.get(url)
    data = response.json()

    video_urls = []
    for item in data['items']:
        if item['id']['kind'] == 'youtube#video':
            video_urls.append(f"https://www.youtube.com/watch?v={item['id']['videoId']}")

    return video_urls

channel_id = "UCaURWQGywYueRti9RMt05hA"
video_urls = get_video_urls(channel_id)
print(video_urls)
# Out:
# ['https://www.youtube.com/watch?v=EyT67WBaLtc', 'https://www.youtube.com/watch?v=OnJ5Xl9L6LE', 'https://www.youtube.com/watch?v=raNzuZHwo60', 'https://www.youtube.com/watch?v=8ST7htl7MzE', 'https://www.youtube.com/watch?v=fSHCG5mwshA', 'https://www.youtube.com/watch?v=vrnWrUXBRlQ', 'https://www.youtube.com/watch?v=DFmKgEgYMVs', 'https://www.youtube.com/watch?v=EUtWEzR3Ozk', 'https://www.youtube.com/watch?v=WZMqnTwywhQ', 'https://www.youtube.com/watch?v=ggjlfSctuek', 'https://www.youtube.com/watch?v=eDm4NL2IZeU', 'https://www.youtube.com/watch?v=ABirzZwfpUM', 'https://www.youtube.com/watch?v=1oMKmORS6EU', 'https://www.youtube.com/watch?v=7zny1NaVeV4', 'https://www.youtube.com/watch?v=jfyu5H5Pgss', 'https://www.youtube.com/watch?v=Aa2R0zD6bKI', 'https://www.youtube.com/watch?v=q6ApUMyGGWA', 'https://www.youtube.com/watch?v=TG24pHWJe6I', 'https://www.youtube.com/watch?v=jXg0Ywni310', 'https://www.youtube.com/watch?v=xiwoTSCXc1E', 'https://www.youtube.com/watch?v=hxIhAUURJf8', 'https://w
# ...

# %%
from tqdm import tqdm

def table_data(video_urls):
    data = pd.DataFrame(columns=['url','name','date','views'])
    for url in tqdm(video_urls):

        video_info = {}
        video_info['url'] = url

        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        video_info['name'] = soup.find('title').text

        video_info['date'] = soup.find("meta", itemprop="datePublished")['content']


        video_info['views'] = int(soup.find('meta', itemprop='interactionCount')['content'])

        video_info_df = pd.DataFrame(video_info, index=[0])

        data = pd.concat([data, video_info_df], ignore_index=True)

    return data

# %%
df = table_data(video_urls)
df
# Out:
# 100%|██████████| 49/49 [00:35<00:00,  1.37it/s]
#                                             url  \
# 0   https://www.youtube.com/watch?v=EyT67WBaLtc
# 1   https://www.youtube.com/watch?v=OnJ5Xl9L6LE
# 2   https://www.youtube.com/watch?v=raNzuZHwo60
# 3   https://www.youtube.com/watch?v=8ST7htl7MzE
# 4   https://www.youtube.com/watch?v=fSHCG5mwshA
# 5   https://www.youtube.com/watch?v=vrnWrUXBRlQ
# 6   https://www.youtube.com/watch?v=DFmKgEgYMVs
# 7   https://www.youtube.com/watch?v=EUtWEzR3Ozk
# 8   https://www.youtube.com/watch?v=WZMqnTwywhQ
# 9   https://www.youtube.com/watch?v=ggjlfSctuek
# 10  https://www.youtube.com/watch?v=eDm4NL2IZeU
# 11  https://www.youtube.com/watch?v=ABirzZwfpUM
# 12  https://www.youtube.com/watch?v=1oMKmORS6EU
# 13  https://www.youtube.com/watch?v=7zny1NaVeV4
# 14  https://www.youtube.com/watch?v=jfyu5H5Pgss
# 15  https://www.youtube.com/watch?v=Aa2R0zD6bKI
# 16  https://www.youtube.com/watch?v=q6ApUMyGGWA
# ...

# %% [markdown]
# # Создание совместных таблиц

# %%
crimes_df = df
crimes_df.index = pd.to_datetime(crimes_df.index, format='%d.%m.%Y')
crimes_yearly_df = crimes_df.resample('Y').sum()
crimes_yearly_df.index = crimes_yearly_df.index.strftime('%Y')
crimes_yearly_df.index.name = 'Year'

migration_df = df_1
crimes_and_migration_df = pd.concat([crimes_yearly_df, migration_df], axis=1)
crimes_and_migration_df.index = crimes_and_migration_df.index.astype(int)
crimes_and_migration_df = crimes_and_migration_df[~((crimes_and_migration_df.index < 2003) | (crimes_and_migration_df.index > 2020))]
crimes_and_migration_df
# Out:
#       Total_crimes    Serious  Huge_damage  Ecological  Terrorism  Extremism  \
# 2003     2756398.0  1080151.0     221379.0     26097.0     8664.0      157.0
# 2004     2893810.0   936804.0     193533.0     30753.0     9523.0      130.0
# 2005     3554738.0  1076988.0     208976.0     33491.0     5438.0      152.0
# 2006     3855373.0  1074501.0     269471.0     41883.0     1781.0      263.0
# 2007     3582541.0   961133.0     298440.0     41242.0      759.0      356.0
# 2008     3209862.0   851392.0     312093.0     44883.0      642.0      460.0
# 2009     2994820.0   796224.0     314990.0     46607.0      654.0      548.0
# 2010     2628799.0   684347.0     290018.0     39155.0      581.0      656.0
# 2011     2404807.0   607507.0     291089.0     29151.0      622.0      619.0
# 2012     2302168.0   569804.0     308759.0     27583.0      637.0      696.0
# 2013     2206249.0   537664.0     529401.0     24728.0      661.0      946.0
# ...

# %%
crimes_and_migration_df['Миграционный прирост'] = pd.to_numeric(crimes_and_migration_df['Миграционный прирост'])
correlation_total_and_migration = crimes_and_migration_df['Total_crimes'].corr(crimes_and_migration_df['Миграционный прирост'])
correlation_terror_and_migration = crimes_and_migration_df['Terrorism'].corr(crimes_and_migration_df['Миграционный прирост'])
correlation_extremism_and_migration = crimes_and_migration_df['Extremism'].corr(crimes_and_migration_df['Миграционный прирост'])
correlation_drugs_and_migration = crimes_and_migration_df['Drugs'].corr(crimes_and_migration_df['Миграционный прирост'])
correlation_weapon_and_migration = crimes_and_migration_df['Weapons'].corr(crimes_and_migration_df['Миграционный прирост'])
correlation_murder_and_migration = crimes_and_migration_df['Murder'].corr(crimes_and_migration_df['Миграционный прирост'])
correlation_rape_and_migration = crimes_and_migration_df['Rape'].corr(crimes_and_migration_df['Миграционный прирост'])

print("Корреляция между МП и общим количеством преступлений:", correlation_total_and_migration)
print("Корреляция между МП и преступлений, связанных с терроризмом:", correlation_terror_and_migration)
print("Корреляция между МП и преступлений, связанных с экстремизмом:", correlation_extremism_and_migration)
print("Корреляция между МП и преступлений, связанных с наркотиками:", correlation_drugs_and_migration)
print("Корреляция между МП и преступлений, связанных с оружием:", correlation_weapon_and_migration)
print("Корреляция между МП и преступлений, связанных с убийствами:", correlation_murder_and_migration)
print("Корреляция между МП и преступлений, связанных с изнасилованиями:", correlation_rape_and_migration)
# Out:
# Корреляция между МП и общим количеством преступлений: -0.07779446595250357
# Корреляция между МП и преступлений, связанных с терроризмом: -0.7151861415083668
# Корреляция между МП и преступлений, связанных с экстремизмом: 0.49551139636531294
# Корреляция между МП и преступлений, связанных с наркотиками: 0.5496441490386328
# Корреляция между МП и преступлений, связанных с оружием: -0.163164136974491
# Корреляция между МП и преступлений, связанных с убийствами: -0.5151879949800795
# Корреляция между МП и преступлений, связанных с изнасилованиями: -0.4282472218723089
